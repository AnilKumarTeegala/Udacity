# %% [markdown]
# Congratulations! You have just completed Intel Edge AI Scholarship Foundation Course, OpenVINO Fundamentals! Please feel free to print or share this certificate on Social Media to celebrate your success!🎉🎉🎉

# %% [markdown]
# ![image.png](attachment:image.png)
